# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshkotkar/AI-agents-/blob/main/pydantic_for_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydantic
! pip install langchain_google_genai

# %%
from pydantic import BaseModel,Field

# %%
class human(BaseModel):
  f_name:str
  l_name:str
  age:int
spiderman=human(f_name="peter",l_name="parker",age=18)
print(spiderman)
# Out:
# f_name='peter' l_name='parker' age=18

# %%
from pydantic import BaseModel

class address(BaseModel):
  street:str
  city:str
  zip:int

class customer(BaseModel):
  name:str
  id:int
  address:address # nested looping

#create a customer with nested address
cust1=customer(
    name="tony",
    id=98711,
    address={"street":"queens street","city":"newyork","zip":1000}
)
print(cust1)
# Out:
# name='tony' id=98711 address=address(street='queens street', city='newyork', zip=1000)

# %% [markdown]
# ##LLM: Structured Extraction

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import getpass
import os
os.environ["GOOGLE_API_KEY"]=getpass.getpass("enter your api key:")
# Out:
# enter your api key:··········

# %%
class extractschema(BaseModel):

  name:str= Field(description="name of the user")
  age:int=Field(description="age of the user")
  edu:str=Field(description="Education of the user")
  is_emp:bool=Field(description="is user emp or not")

# %% [markdown]
# ##LLM binding

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0)

# %%
schema = llm.with_structured_output(extractschema) # This line transforms your Pydantic model into a strict blueprint for validated output

# %%
result=schema.invoke("spiderman age is 21 and he data science student work at IBM")

# %%
print(f"Name: {result.name}")
print(f"age: {result.age}")
print(f"edu:  {result.edu}")
print(f"emp: {result.is_emp}")
# Out:
# Name: spiderman
# age: 21
# edu:  data science student
# emp: True
